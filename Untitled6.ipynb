# %% [markdown]
# <a href="https://colab.research.google.com/github/biradarshubhangi586-lab/Python-1/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tup = (5, 2, 9, 1, 7)

# Length
print("Length:", len(tup))

# Maximum
print("Max value:", max(tup))

# Minimum
print("Min value:", min(tup))
# Out:
# Length: 5
# Max value: 9
# Min value: 1

# %%
a = [10, 20, 30, 40]

print("List:", a)

print(20 in a)
print(50 not in a)
# Out:
# List: [10, 20, 30, 40]
# True
# True

# %%
a = [10, 20, 30, 40, 50]

print(a[0])      # first element
print(a[-1])     # last element
print(a[1:4])    # slicing
# Out:
# 10
# 50
# [20, 30, 40]

# %%
a = [1, 2, 3, 4]

a[1] = 20
print(a)

a.append(5)
print(a)

a.insert(1, 100)
print(a)

a.remove(20)
print(a)
# Out:
# [1, 20, 3, 4]
# [1, 20, 3, 4, 5]
# [1, 100, 20, 3, 4, 5]
# [1, 100, 3, 4, 5]

# %%
a = [1, 2, 3]
b = [4, 5]

c = a + b
print(c)

print(a * 2)

print(len(a))
print(max(a))
print(min(a))
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 3, 1, 2, 3]
# 3
# 3
# 1
